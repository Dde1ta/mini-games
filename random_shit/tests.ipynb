# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
def dis(x, y):
    return ((x[1] - y[1]) ** 2 + (x[0] - y[0]) ** 2)**0.5

# %%
dis([1,2], [4,3])
# Out:
# 3.1622776601683795

# %%
dis([5,2], [4,3])
# Out:
# 1.4142135623730951

# %%
import numpy as np

data = {

}
